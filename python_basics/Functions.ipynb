# %%
def add(a,b):
    return a+b

print add(4,5)
# Out:
# 9

# %%
def add_product(a,b):
    return a+b, a*b

a,b= add_product(3,4)
print a
print b
# Out:
# 7
# 12

# %%
from multiprocessing import Pool
a= [3,4]*500

# %%
def square(x):
    return x*x

# %%
f=[square(b) for b in a]

# %%
p=Pool(4)
p.map(square, a)
# Out:
# [9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
#  16,
#  9,
# ...
